# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize
import json
import pprint

url = "https://api.bscscan.com/api?module=account&action=txlist&address=0xa5DeC77c4d1B4eba2807C9926b182812A0cBf9Eb&startblock=0&endblock=99999999&page=1&offset=10&sort=asc&apikey=HTU63DF6739HRD1RV7W4Y6B99JR5X7BSUW"

response2 = requests.request("GET", url)
print (response2.json())

pp = pprint.PrettyPrinter(indent=4)
# Out:
# {'status': '1', 'message': 'OK', 'result': [{'blockNumber': '16310659', 'timeStamp': '1648043664', 'hash': '0x727e5c5a66cc9e0f29910b48d16afdc749cea7fe9712f4c4f2ba4dc874ab477a', 'nonce': '1', 'blockHash': '0x8ab5fcaa0f5fd88b4105bfe69ea3f2bbf60efb4948e23bff2cb5e2126a5b5407', 'transactionIndex': '227', 'from': '0x2e8766620f1b855663860eb7ddeb0679dd4d89bf', 'to': '', 'value': '0', 'gas': '1201556', 'gasPrice': '5000000000', 'isError': '0', 'txreceipt_status': '1', 'input': '...', 'contractAddress': '0xa5dec77c4d1b4eba2807c9926b182812a0cbf9eb', 'cumulativeGasUsed': '48962413', 'gasUsed': '1201556', 'confirmations': '8549990', 'methodId': '0x60806040', 'functionName': 'atInversebrah(int248 a, uint48[] b, uint32 c, bytes20[] d, bytes30[] e)'}, {'blockNumber': '16323421', 'timeStamp': '1648082310', 'hash': '0xc52f97e6b744c19ea7d7a618c913f5d530b30e46648648a6e5cd2a3f2d7ba1ce', 'nonce': '0', 'blockHash': '0xf1fc91ef126929ceedecb84803ddd110f574d95623365ec8785236fb4b4ac4c3', 'transactionIndex': '1
# ...
